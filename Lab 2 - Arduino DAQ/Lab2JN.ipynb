# %% [markdown]
# # Lab 2 Notebook

# %% [markdown]
# Add in the libraries (we always do this so that the code works).

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

from scipy.signal import welch # We'll need this for power spectral density estimation eventually

# Allow for interactive plotting in Jupyter notebooks, comment out the line to turn this off. 
# The % sign is a Jupyter magic command that enables the use of widgets in the notebook.
# This requires installing the ipympl package, so if you get an error on this line, 
# you may need to install it first by running: pip install ipympl

# %matplotlib widget 

# For interactive data point selection in plots, this library is useful.
import mplcursors 

# Add this line of code to each plot if you want cursors: 
# mplcursors.cursor(hover=False, multiple=True)  # Enable interactive cursor for data point selection, right-click to remove cursor

# Use this command to set the default font size for your plots.
sns.set_context("notebook")
# Options from smallest to largest: "paper", "notebook", "talk", "poster"

# %% [markdown]
# # Part 2: Arduino Data Collection

# %% [markdown]
# This is the code that produces the plot that shows clipping.

# %%
# import the dataset, view the first few rows
myLab = pd.read_csv("Lab2.0data.csv") # Make sure to update this file name to match your data! 
myLab.head() #This will display the first few rows of the DataFrame
# Out:
#    Time (ms)  Sensor 0 (raw)  Sensor 1 (raw)  Sensor 2 (raw)
# 0          4             404             162             199
# 1          8             270             111             135
# 2         12             183              71              90
# 3         16             124              50              62
# 4         20              89              47              52

# %%
myLab['Sensor 1 (V)']= myLab['Sensor 1 (raw)'] * (5.06/1023.0) # Convert raw sensor data to volts using the provided conversion factor

plt.figure()  # Create a new figure
sns.lineplot(x="Time (ms)", y="Sensor 1 (V)", data=myLab)
plt.title("Sensor 1 vs Time")
plt.xlabel("Time (ms)")
plt.ylabel("Sensor 1 (V)")

mplcursors.cursor(hover=False)  # Enable interactive cursor for data point selection
# Click anywhere on your data to add a cursor
# Right-click to remove a cursor

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# This is the segment where we offset the signal to be higher so that there is no clipping.

# %%
# import the dataset, view the first few rows
myLab2 = pd.read_csv("Lab2data.csv") # Make sure to update this file name to match your data! 
myLab2.head() #This will display the first few rows of the DataFrame
# Out:
#    Time (ms)  Sensor 0 (raw)  Sensor 1 (raw)  Sensor 2 (raw)
# 0          4             406             201             226
# 1          8             282             154             171
# 2         12             210             143             149
# 3         16             174             122             129
# 4         20             145              92             102

# %%
myLab2['Sensor 1 (V)']= myLab2['Sensor 1 (raw)'] * (5.06/1023.0) # Convert raw sensor data to volts using the provided conversion factor

plt.figure()  # Create a new figure
sns.lineplot(x="Time (ms)", y="Sensor 1 (V)", data=myLab2)
plt.title("Sensor 1 vs Time")
plt.xlabel("Time (ms)")
plt.ylabel("Sensor 1 (V)")

mplcursors.cursor(hover=False)  # Enable interactive cursor for data point selection
# Click anywhere on your data to add a cursor
# Right-click to remove a cursor

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Part 3: Aliasing and Bit Noise

# %%
# import the dataset, view the first few rows
myLab2_3 = pd.read_csv("Lab2.1data.csv") # Make sure to update this file name to match your data! 
myLab2_3.head() #This will display the first few rows of the DataFrame
# Out:
#    Time (ms)  Sensor 0 (raw)  Sensor 1 (raw)  Sensor 2 (raw)
# 0          4             404             211             232
# 1          8             292             165             181
# 2         12             218             131             144
# 3         16             168             117             123
# 4         20             141             116             117

# %%
myLab2_3['Sensor 1 (V)']= myLab2_3['Sensor 1 (raw)'] * (5.06/1023.0) # Convert raw sensor data to volts using the provided conversion factor

plt.figure()  # Create a new figure
sns.lineplot(x="Time (ms)", y="Sensor 1 (V)", data=myLab2_3)
plt.title("Sensor 1 vs Time")
plt.xlabel("Time (ms)")
plt.ylabel("Sensor 1 (V)")

mplcursors.cursor(hover=False)  # Enable interactive cursor for data point selection
# Click anywhere on your data to add a cursor
# Right-click to remove a cursor

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# Bit Noise

# %%
# import the dataset, view the first few rows
myLab2_4 = pd.read_csv("Lab2.2data.csv") # Make sure to update this file name to match your data! 
myLab2_4.head() #This will display the first few rows of the DataFrame
# Out:
#    Time (ms)  Sensor 0 (raw)  Sensor 1 (raw)  Sensor 2 (raw)
# 0          4             405             209             231
# 1          8             289             167             182
# 2         12             221             143             152
# 3         16             176             124             131
# 4         20             145             113             116

# %%
myLab2_4['Sensor 1 (V)']= myLab2_4['Sensor 1 (raw)'] * (5.06/1023.0) # Convert raw sensor data to volts using the provided conversion factor

plt.figure()  # Create a new figure
sns.lineplot(x="Time (ms)", y="Sensor 1 (V)", data=myLab2_4)
plt.title("Sensor 1 vs Time")
plt.xlabel("Time (ms)")
plt.ylabel("Sensor 1 (V)")

mplcursors.cursor(hover=False)  # Enable interactive cursor for data point selection
# Click anywhere on your data to add a cursor
# Right-click to remove a cursor

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Part 4: Post-Processing

# %% [markdown]
# Part 2: Final Signal PSD Plot

# %%
# Definte input parameters for Welch's method
segment_size = 512 # Size of each segment for Welch's method, should be a power of 2 (e.g. 256, 512, 1024, 2048, 4096)
overlap_pct = 60 # Percentage of overlap between segments, typically 25-75% (must be < 100%)
overlap_size = int(segment_size * overlap_pct / 100) # Calculate the number of samples to overlap between segments
# Ensure noverlap < nperseg (overlap_size < segment_size)
assert overlap_size < segment_size, f"Error: noverlap ({overlap_size}) must be less than nperseg ({segment_size})"

# Compute Power Spectral Density using Welch's method
f, pxx = welch(myLab2['Sensor 1 (V)'], fs= 250, window="hann", nperseg=segment_size, noverlap=overlap_size)

# f is the frequency vector, pxx is the power spectral density estimate
# For more details, see the documentation https://docs.scipy.org/doc/scipy/reference/generated/scipy.signal.welch.html

plt.figure()
sns.lineplot(x=f, y=pxx, marker = '*')
plt.xscale('log')  # Logarithmic scale for frequency axis
plt.yscale('log')  # Logarithmic scale for power spectral density
plt.xlim([20, 20000])  # Limit x-axis to typical audio frequency range
plt.xlabel('Frequency (Hz)')
plt.ylabel('PSD Amplitude (Arbitrary Units)')
plt.title('Final Signal PSD Plot')
plt.grid(True)
mplcursors.cursor(hover=False)  # Enable interactive cursor for data point selection
plt.show()
# Out:
# c:\Users\MylaGrace\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\signal\_spectral_py.py:2017: UserWarning: nperseg = 512 is greater than input length  = 500, using nperseg = 500
#   warnings.warn('nperseg = {0:d} is greater than input length '
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# Part 3 Aliasing PSD Plot

# %%
# Definte input parameters for Welch's method
segment_size = 512 # Size of each segment for Welch's method, should be a power of 2 (e.g. 256, 512, 1024, 2048, 4096)
overlap_pct = 60 # Percentage of overlap between segments, typically 25-75%
overlap_size = int(segment_size * overlap_pct / 100) # Calculate the number of samples to overlap between segments

# Compute Power Spectral Density using Welch's method
f, pxx = welch(myLab2_3['Sensor 1 (V)'], fs= 250, window="hann", nperseg=segment_size, noverlap=overlap_size)

# f is the frequency vector, pxx is the power spectral density estimate
# For more details, see the documentation https://docs.scipy.org/doc/scipy/reference/generated/scipy.signal.welch.html

plt.figure()
sns.lineplot(x=f, y=pxx, marker = '*')
plt.xscale('log')  # Logarithmic scale for frequency axis
plt.yscale('log')  # Logarithmic scale for power spectral density
plt.xlim([20, 20000])  # Limit x-axis to typical audio frequency range
plt.xlabel('Frequency (Hz)')
plt.ylabel('PSD Amplitude (Arbitrary Units)')
plt.title('Aliasing PSD Plot')
plt.grid(True)
mplcursors.cursor(hover=False)  # Enable interactive cursor for data point selection
plt.show()
# Out:
# c:\Users\MylaGrace\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\signal\_spectral_py.py:2017: UserWarning: nperseg = 512 is greater than input length  = 500, using nperseg = 500
#   warnings.warn('nperseg = {0:d} is greater than input length '
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
